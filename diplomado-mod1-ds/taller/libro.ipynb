# %% [markdown]
# # Punto 1

# %%
import pandas as pd

# Cargar datos
df = pd.read_csv('../taller/user_loggedin_teacher.csv', delimiter=',')

# Convierte todos los valores de la columna department a minúsculas
df['department'] = df['department'].str.lower()

# Ordenar la columna "department" alfabéticamente y mostrar toda la columna
df = df.sort_values(by="department")
pd.set_option('display.max_rows', None)  # Muestra todas las filas
df[['department']]  # Muestra solo la columna 'department'
# Out:
#                                           department
# 2891                             ingeniería mecánica
# 5924                             ingeniería mecánica
# 3258                             ingeniería mecánica
# 5920                             ingeniería mecánica
# 12702                            ingeniería mecánica
# 3181                             ingeniería mecánica
# 12681                            ingeniería mecánica
# 3132                             ingeniería mecánica
# 10822                            ingeniería mecánica
# 3090                             ingeniería mecánica
# 1996                             ingeniería mecánica
# 1995                             ingeniería mecánica
# 4824                             ingeniería mecánica
# 1992                             ingeniería mecánica
# 8724                             ingeniería mecánica
# 8310                             ingeniería mecánica
# 69                               ingeniería mecánica
# ...

# %%
# Corregir las variaciones comunes de manera general
df['department'] = df['department'].replace({
    'departamento de geografía y medio ambien': 'departamento de geografía y medio ambiente',
    'departamento de matemáticas y estadístic': 'departamento de matemáticas y estadística',
    'departamento de salud pblica': 'departamento de salud pública',
    'dpto ciencias administrativas': 'departamento ciencias administrativas',
    'dpto de ciencias naturales': 'departamento ciencias naturales',
    'dpto de ingeniería ambiental':' departamento de ingeniería ambiental',
    'dpto de ing de sistemas y telecomunicaci':'departamento de ing de sistemas y telecomunicaciones',
    'dpto de ing agronómica y desarroll rural':'departamento de ing agronómica y desarrollo rural',
    'dpto de cultura fsica, recreac y deport':'departamento de cultura fisica, recreacion y deporte',
    'regencia de farmacia':'departamento de regencia de farmacia',
    'psicopedagogia':'departamento de psicopedagogia',
    'matematica y estadistica':'departamento de matematicas y estadistica',
    'lic en informática':'departamento de licenciatura en informatica',
    'ingeniería ambiental ':'departamento de ingeniería ambiental',
    'ingeniería ':'departamento de ingeniería',
    'informática':'departamento de informática',
    'geografía':'departamento de geografía',
    'fsica':'departamento de fisica',
    'enfermería':'departamento de enfermería',
    'informatica':'departamento de licenciatura en informatica',
    'ingeniería mecánica':'departamento de ingeniería mecánica',
    'administración en salud':'departamento de administración en salud',
    'departamento de salud publica d p':'departamento de salud publica',
    'departamento de informtica educativa':'departamento de informática educativa',
    'departamento de idiomas extranjeros d p':'departamento de idiomas extranjeros',
    'departamento de geografa y medio ambien':'departamento de geografía y medio ambiente',
    'departamento de fisica y electronica d p':'departamento de fisica y electronica',
    'departamento de enfermeria d p':'departamento de enfermería',
    'departamento de bacteriologia d p':'departamento de bacteriologia',
    'decanatura facultad de ciencias agricolas d p':'departamento de ciencias agricolas',
    ' ingeniería mecánica':'departamento de ingenieria mecanica',
    'departamento de ciencias acuicolas d p':'departamento de ciencias agricolas',
    'biologia':'departamento de biología',
    'ciencias jurídicas':'departamento de ciencias jurídicas',
    'departamento ciencias administrativas':'departamento de ciencias administrativas',
    'departamento ciencias naturales':'departamento de ciencias naturales',
    'departamento de bacteriologia':'departamento de bacteriología',
    'departamento de ciencias jurdicas':'departamento de ciencias jurídicas',
    'departamento de fisica y electronica':'departamento de física y electrónica',
    'departamento de fisica y electrónica':'departamento de física y electrónica',
    'departamento de geografía':'departamento de geografía y medio ambiente',
    'departamento de ingenieria ambiental d p':'departamento de ingenieria ambiental',
    'departamento de ingenieria mecanica':'departamento de ingeniería mecánica',
    'departamento de ingenieria mecánica':'departamento de ingeniería mecánica',
    'departamento de matematicas y estadistica':'departamento de matemáticas y estadística',
    'departamento de psicopedagoga':'departamento de psicopedagogia',
    'departamento de psicopedagogia':'departamento de psicopedagogía',
    'departamento de regencia de farmacia':'departamento de regencía y farmacia',
    'departamento de salud publica':'departamento de salud pública',
    'dpto de cultura física, recreac y deport':'departamento de cultura física, recreación y deporte',
    'enfermería ':'departamento de enfermería',
    
})

df['department'].unique()
# Out:
# array(['departamento de ingenieria mecanica',
#        'departamento de administración en salud',
#        'departamento de biología', 'departamento de ciencias jurídicas',
#        'departamento de ciencias agricolas', 'departamento de artes',
#        'departamento de bacteriologia', 'departamento de bacteriología',
#        'departamento de ciencias acuícolas',
#        'departamento de ciencias pecuarías',
#        'departamento de ciencias sociales', 'departamento de enfermería',
#        'departamento de español y literatura',
#        'departamento de fisica y electronica',
#        'departamento de física y electrónica',
#        'departamento de geografía y medio ambiente',
#        'departamento de idiomas extranjeros',
#        'departamento de informática educativa',
#        'departamento de ingenieria ambiental',
#        'departamento de ingeniería de alimentos',
#        'departamento de ingeniería industrial',
#        'departamento de ingeniería mecánica',
# ...

# %%
# Guarda el DataFrame en el archivo CSV
# df.to_csv("user_loggedin_teacher1.csv", index=False)
