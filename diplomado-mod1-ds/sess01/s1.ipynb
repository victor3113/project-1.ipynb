# %% [markdown]
# # Sesion 2 - Data Exploration and Prepprocessing
# -----------

# %%
#load lib
import pandas as pd

# %%
data = pd.read_csv('../data/percent_bachelors_degrees_women_usa.csv', delimiter=',')
print(data)
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 0   1970          NaN     11.921005                 59.7  29.088363
# 1   1970          NaN     11.921005                 59.7  29.088363
# 2   1970          NaN     11.921005                 59.7  29.088363
# 3   1970          NaN     11.921005                 59.7  29.088363
# 4   1970          NaN     11.921005                 59.7  29.088363
# 5   1971     5.452797     12.003106                 59.9  29.394403
# 6   1971     5.452797     12.003106                 59.9  29.394403
# 7   1971     5.452797     12.003106                 59.9  29.394403
# 8   1971     5.452797     12.003106                 59.9  29.394403
# 9   1972     7.420710     13.214594                 60.4  29.810221
# 10  1973     9.653602     14.791613                 60.2  31.147915
# 11  1974    14.074623     17.444688                 61.9  32.996183
# 12  1975    18.333162     19.134048                 60.9  34.449902
# ...

# %%
#mirar las primeras 5 filas
data.head(5)
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology  Business  \
# 0  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 1  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 2  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 3  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 4  1970          NaN     11.921005                 59.7  29.088363  9.064439
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.3              13.6  74.535328          0.8
# 2                           35.3              13.6  74.535328          0.8
# 3                           35.3              13.6  74.535328          0.8
# 4                           35.3              13.6  74.535328          0.8
#
# ...

# %%
#mirar las ultimas 5 filas
data.tail(5)
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 44  2007    47.605026     43.100459                 61.4  59.411993
# 45  2008    47.570834     42.711730                 60.7  59.305765
# 46  2009    48.667224     43.348921                 61.0  58.489583
# 47  2010    48.730042     42.066721                 61.3  59.010255
# 48  2011    50.037182     42.773438                 61.2  58.742397
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 44  49.000459                           62.5              17.6  78.721413
# 45  48.888027                           62.4              17.8  79.196327
# 46  48.840474                           62.8              18.1  79.532909
# 47  48.757988                           62.5              17.6  79.618625
# 48  48.180418                           62.2              18.2  79.432812
#
#     Engineering    English  Foreign Languages  Health Professions  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           49 non-null     int64
#  1   Agriculture                    44 non-null     float64
#  2   Architecture                   49 non-null     float64
#  3   Art and Performance            49 non-null     float64
#  4   Biology                        49 non-null     float64
#  5   Business                       49 non-null     float64
#  6   Communications and Journalism  49 non-null     float64
#  7   Computer Science               49 non-null     float64
#  8   Education                      49 non-null     float64
#  9   Engineering                    49 non-null     float64
#  10  English                        49 non-null     float64
#  11  Foreign Languages              49 non-null     float64
# ...

# %%
#mostrar las cantidad de columnas y filas
data.shape
# Out:
# (49, 18)

# %%
#mostrar los conjuntos de datos sin valores numericos o nulos, eliminar los nulos
#no reemplaza, retorna con los valores ya eliminados
data.dropna()
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 5   1971     5.452797     12.003106                 59.9  29.394403
# 6   1971     5.452797     12.003106                 59.9  29.394403
# 7   1971     5.452797     12.003106                 59.9  29.394403
# 8   1971     5.452797     12.003106                 59.9  29.394403
# 9   1972     7.420710     13.214594                 60.4  29.810221
# 10  1973     9.653602     14.791613                 60.2  31.147915
# 11  1974    14.074623     17.444688                 61.9  32.996183
# 12  1975    18.333162     19.134048                 60.9  34.449902
# 13  1976    22.252760     21.394491                 61.3  36.072871
# 14  1977    24.640177     23.740541                 62.0  38.331386
# 15  1978    27.146192     25.849240                 62.5  40.112496
# 16  1979    29.633365     27.770477                 63.2  42.065551
# 17  1980    30.759390     28.080381                 63.4  43.999257
# ...

# %%
#mostrar en un nuevo dataframe los datos con los valores faltantes elimindos
data_dropna = data.dropna()
data_dropna
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 5   1971     5.452797     12.003106                 59.9  29.394403
# 6   1971     5.452797     12.003106                 59.9  29.394403
# 7   1971     5.452797     12.003106                 59.9  29.394403
# 8   1971     5.452797     12.003106                 59.9  29.394403
# 9   1972     7.420710     13.214594                 60.4  29.810221
# 10  1973     9.653602     14.791613                 60.2  31.147915
# 11  1974    14.074623     17.444688                 61.9  32.996183
# 12  1975    18.333162     19.134048                 60.9  34.449902
# 13  1976    22.252760     21.394491                 61.3  36.072871
# 14  1977    24.640177     23.740541                 62.0  38.331386
# 15  1978    27.146192     25.849240                 62.5  40.112496
# 16  1979    29.633365     27.770477                 63.2  42.065551
# 17  1980    30.759390     28.080381                 63.4  43.999257
# ...

# %%
data_dropna.shape
# Out:
# (44, 18)

# %%
#craer un dataframe donde rellene los valores nulos con un valor
data_fillna = data.fillna(0)
data_fillna.head(10)
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     0.000000     11.921005                 59.7  29.088363   9.064439
# 1  1970     0.000000     11.921005                 59.7  29.088363   9.064439
# 2  1970     0.000000     11.921005                 59.7  29.088363   9.064439
# 3  1970     0.000000     11.921005                 59.7  29.088363   9.064439
# 4  1970     0.000000     11.921005                 59.7  29.088363   9.064439
# 5  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 6  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 7  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 8  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 9  1972     7.420710     13.214594                 60.4  29.810221  10.558962
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# ...

# %%
#mostras la informacion de los datos de una fila
data.iloc[5]
# Out:
# Year                             1971.000000
# Agriculture                         5.452797
# Architecture                       12.003106
# Art and Performance                59.900000
# Biology                            29.394403
# Business                            9.503187
# Communications and Journalism      35.500000
# Computer Science                   13.600000
# Education                          74.149204
# Engineering                         1.000000
# English                            64.556485
# Foreign Languages                  73.900000
# Health Professions                 75.500000
# Math and Statistics                39.000000
# Physical Sciences                  14.900000
# Psychology                         46.200000
# Public Administration              65.500000
# Social Sciences and History        36.200000
# Name: 5, dtype: float64

# %%
#mostras varias filas, como lista
data.iloc[[5,6,7]]
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology  Business  \
# 5  1971     5.452797     12.003106                 59.9  29.394403  9.503187
# 6  1971     5.452797     12.003106                 59.9  29.394403  9.503187
# 7  1971     5.452797     12.003106                 59.9  29.394403  9.503187
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 5                           35.5              13.6  74.149204          1.0
# 6                           35.5              13.6  74.149204          1.0
# 7                           35.5              13.6  74.149204          1.0
#
#      English  Foreign Languages  Health Professions  Math and Statistics  \
# 5  64.556485               73.9                75.5                 39.0
# 6  64.556485               73.9                75.5                 39.0
# 7  64.556485               73.9                75.5                 39.0
#
#    Physical Sciences  Psychology  Public Administration  \
# ...

# %%
#crear un nuevo dataframe etiquetado
data_taged = pd.DataFrame({'COL1': [1,2,3],
                           'COL2': [4,5,6],
                           'COL3': [7,8,9]},
                          index=['a','b','c']
                          )
data_taged
# Out:
#    COL1  COL2  COL3
# a     1     4     7
# b     2     5     8
# c     3     6     9

# %%
data_taged.loc[['a','b']]
# Out:
#    COL1  COL2  COL3
# a     1     4     7
# b     2     5     8

# %%
#identificar las filas repetidas
data.duplicated()
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# dtype: bool

# %%
#pasar como parametros series
data[data.duplicated()]
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology  Business  \
# 1  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 2  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 3  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 4  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 6  1971     5.452797     12.003106                 59.9  29.394403  9.503187
# 7  1971     5.452797     12.003106                 59.9  29.394403  9.503187
# 8  1971     5.452797     12.003106                 59.9  29.394403  9.503187
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 1                           35.3              13.6  74.535328          0.8
# 2                           35.3              13.6  74.535328          0.8
# 3                           35.3              13.6  74.535328          0.8
# ...

# %%
#mostrar las que no estan duplicadas
data.drop_duplicates()
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 0   1970          NaN     11.921005                 59.7  29.088363
# 5   1971     5.452797     12.003106                 59.9  29.394403
# 9   1972     7.420710     13.214594                 60.4  29.810221
# 10  1973     9.653602     14.791613                 60.2  31.147915
# 11  1974    14.074623     17.444688                 61.9  32.996183
# 12  1975    18.333162     19.134048                 60.9  34.449902
# 13  1976    22.252760     21.394491                 61.3  36.072871
# 14  1977    24.640177     23.740541                 62.0  38.331386
# 15  1978    27.146192     25.849240                 62.5  40.112496
# 16  1979    29.633365     27.770477                 63.2  42.065551
# 17  1980    30.759390     28.080381                 63.4  43.999257
# 18  1981    31.318655     29.841694                 63.3  45.249512
# 19  1982    32.636664     34.816248                 63.1  45.967338
# ...

# %%
#mostrar las filas que no estan duplicadas
data_drop_duplicates = data.drop_duplicates()
data_drop_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42 entries, 0 to 48
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           42 non-null     int64
#  1   Agriculture                    41 non-null     float64
#  2   Architecture                   42 non-null     float64
#  3   Art and Performance            42 non-null     float64
#  4   Biology                        42 non-null     float64
#  5   Business                       42 non-null     float64
#  6   Communications and Journalism  42 non-null     float64
#  7   Computer Science               42 non-null     float64
#  8   Education                      42 non-null     float64
#  9   Engineering                    42 non-null     float64
#  10  English                        42 non-null     float64
#  11  Foreign Languages              42 non-null     float64
# ...

# %%
data.head(5)
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology  Business  \
# 0  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 1  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 2  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 3  1970          NaN     11.921005                 59.7  29.088363  9.064439
# 4  1970          NaN     11.921005                 59.7  29.088363  9.064439
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.3              13.6  74.535328          0.8
# 2                           35.3              13.6  74.535328          0.8
# 3                           35.3              13.6  74.535328          0.8
# 4                           35.3              13.6  74.535328          0.8
#
# ...

# %%
data_copy = data.copy()
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Year                           49 non-null     int64
#  1   Agriculture                    44 non-null     float64
#  2   Architecture                   49 non-null     float64
#  3   Art and Performance            49 non-null     float64
#  4   Biology                        49 non-null     float64
#  5   Business                       49 non-null     float64
#  6   Communications and Journalism  49 non-null     float64
#  7   Computer Science               49 non-null     float64
#  8   Education                      49 non-null     float64
#  9   Engineering                    49 non-null     float64
#  10  English                        49 non-null     float64
#  11  Foreign Languages              49 non-null     float64
# ...

# %%
#informacion de las columnas
data.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %%
#muestras aleatorias del dataframe con un 30%
df_random = data.sample(frac=0.3)
df_random
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 36  1999    42.887202     38.631529                 59.2  58.228823
# 40  2003    47.935187     42.758543                 61.1  62.169456
# 9   1972     7.420710     13.214594                 60.4  29.810221
# 29  1992    33.931660     35.202356                 61.0  51.349742
# 26  1989    31.612403     39.096540                 62.0  50.774716
# 0   1970          NaN     11.921005                 59.7  29.088363
# 7   1971     5.452797     12.003106                 59.9  29.394403
# 18  1981    31.318655     29.841694                 63.3  45.249512
# 20  1983    31.635347     35.826257                 62.4  46.713135
# 24  1987    31.486429     38.730675                 61.7  50.209878
# 48  2011    50.037182     42.773438                 61.2  58.742397
# 5   1971     5.452797     12.003106                 59.9  29.394403
# 10  1973     9.653602     14.791613                 60.2  31.147915
# ...

# %%
#muestra un numero determinada y no porcentaje
df_random = data.sample(n=5)
df_random
# Out:
#     Year  Agriculture  Architecture  Art and Performance    Biology  \
# 4   1970          NaN     11.921005                 59.7  29.088363
# 29  1992    33.931660     35.202356                 61.0  51.349742
# 34  1997    40.685685     35.101934                 58.7  54.999469
# 6   1971     5.452797     12.003106                 59.9  29.394403
# 14  1977    24.640177     23.740541                 62.0  38.331386
#
#      Business  Communications and Journalism  Computer Science  Education  \
# 4    9.064439                           35.3              13.6  74.535328
# 29  47.219395                           59.7              28.2  78.435182
# 34  48.561050                           60.0              26.8  75.163701
# 6    9.503187                           35.5              13.6  74.149204
# 14  27.163427                           46.9              25.7  72.456395
#
#     Engineering    English  Foreign Languages  Health Professions  \
# ...

# %%
#obtener la sumatoria de una columna
data.Agriculture.sum()
# Out:
# np.float64(1433.751528272)

# %%
data['Art and Performance'].sum()
# Out:
# np.float64(2984.7)

# %%
#mostrar la cantidad de datos sin incluir los NA
data.Agriculture.count()
# Out:
# np.int64(44)

# %%
#mostrar la cantidad de datos incluyendo los NA
len(data.Agriculture)
# Out:
# 49

# %%
#mostrar cuales son los NA como TRUE
data.isna()
# Out:
#      Year  Agriculture  Architecture  Art and Performance  Biology  Business  \
# 0   False         True         False                False    False     False
# 1   False         True         False                False    False     False
# 2   False         True         False                False    False     False
# 3   False         True         False                False    False     False
# 4   False         True         False                False    False     False
# 5   False        False         False                False    False     False
# 6   False        False         False                False    False     False
# 7   False        False         False                False    False     False
# 8   False        False         False                False    False     False
# 9   False        False         False                False    False     False
# 10  False        False         False                False    False     False
# ...

# %%
#mostrar cuales son los NA como TRUE y su suma
data.isna().sum()
# Out:
# Year                             0
# Agriculture                      5
# Architecture                     0
# Art and Performance              0
# Biology                          0
# Business                         0
# Communications and Journalism    0
# Computer Science                 0
# Education                        0
# Engineering                      0
# English                          0
# Foreign Languages                0
# Health Professions               0
# Math and Statistics              0
# Physical Sciences                0
# Psychology                       0
# Public Administration            0
# Social Sciences and History      0
# dtype: int64

# %%
schools = pd.read_csv('../data/colegios_cordoba_sin_header.csv' , delimiter=';')
schools
# Out:
#       COD_DANE_DEPARTAMENTO Departamento  Cod_sec retaria SECRETARIA  \
# 0                        23      Córdoba             3781    CORDOBA
# 1                        23      Córdoba             3781    CORDOBA
# 2                        23      Córdoba             3781    CORDOBA
# 3                        23      Córdoba             3781    CORDOBA
# 4                        23      Córdoba             3781    CORDOBA
# ...                     ...          ...              ...        ...
# 1326                     23      Córdoba             3781    CORDOBA
# 1327                     23      Córdoba             3781    CORDOBA
# 1328                     23      Córdoba             3781    CORDOBA
# 1329                     23      Córdoba             3781    CORDOBA
# 1330                     23      Córdoba             3781    CORDOBA
#
#       COD_DANE_MUNICIPIO          MUNICIPIO  EST_ID  Codigo Dane EE  \
# 0                  23466        Montelíbano   14615    223466002479
# ...

# %%
#mostrat los municipios sin los duplicados
schools.MUNICIPIO.unique()
# Out:
# array(['Montelíbano', 'Cerete', 'Tuchín', 'Puerto Libertador',
#        'Planeta Rica', 'Los Córdobas', 'San Antero', 'Chinu',
#        'Cienaga De Oro', 'Tierralta', 'Momil', 'Purísima', 'Ayapel',
#        'Valencia', 'Moñitos', 'San Bernardo Del Viento', 'La Apartada',
#        'San José de Uré', 'San Andrés de Sotavento', 'San Pelayo',
#        'San Carlos', 'Buenavista', 'Cotorra', 'Canalete', 'Pueblo Nuevo',
#        'Puerto Escondido', 'Chimá'], dtype=object)

# %%
#mostrat los municipios sin los duplicados y en MAYUSCULA
schools.MUNICIPIO.str.upper()
# Out:
# 0             MONTELÍBANO
# 1                  CERETE
# 2             MONTELÍBANO
# 3                  TUCHÍN
# 4       PUERTO LIBERTADOR
#               ...
# 1326      SAN JOSÉ DE URÉ
# 1327               CERETE
# 1328         PLANETA RICA
# 1329    PUERTO LIBERTADOR
# 1330               AYAPEL
# Name: MUNICIPIO, Length: 1331, dtype: object

# %%
#exportar como excel los datos no duplicados
data_drop_duplicates.to_excel("data_drop_duplicates.xlsx","sin_duplicate")
# Out:
# C:\Users\CAMBER\AppData\Local\Temp\ipykernel_4036\1691107987.py:2: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   data_drop_duplicates.to_excel("data_drop_duplicates.xlsx","sin_duplicate")
